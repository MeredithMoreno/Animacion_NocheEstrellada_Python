# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
from PIL import Image
from IPython.display import display
import imutils

# %%
lanoche = cv2.imread('lanoche.png', cv2.IMREAD_UNCHANGED)

if lanoche.shape[2] == 3:
    lanoche = cv2.cvtColor(lanoche, cv2.COLOR_BGR2BGRA)

# %%
lanoche_cropped1 = lanoche[0:168, 310:608]
plt.imshow(lanoche_cropped1)

# %%
lanoche_cropped4 = lanoche[0:274, 122:608]
plt.imshow(lanoche_cropped4)

# %%
lanoche_cropped5 = lanoche[0:284, 103:608]
plt.imshow(lanoche_cropped5)

# %%
lanoche_cropped6 = lanoche[0:315, 49:608]
plt.imshow(lanoche_cropped6)

# %%
lanoche_cropped7 = lanoche[0:342, 0:608]
plt.imshow(lanoche_cropped7)
